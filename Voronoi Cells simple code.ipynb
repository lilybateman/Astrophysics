# %%
import matplotlib.pyplot as plt
import numpy as np
points = np.random.rand(10,2) #random
print(points)

from scipy.spatial import Voronoi, voronoi_plot_2d
vor = Voronoi(points)
fig = voronoi_plot_2d(vor)
fig = voronoi_plot_2d(vor, show_vertices=False, line_colors='orange',
line_width=3, line_alpha=0.6, point_size=2)
plt.show()
# Out:
# [[0.18068749 0.64358599]
#  [0.01130044 0.20377151]
#  [0.948345   0.34551095]
#  [0.88277857 0.1269636 ]
#  [0.23296368 0.55071864]
#  [0.5700543  0.93179281]
#  [0.45747337 0.63685832]
#  [0.32546539 0.2955118 ]
#  [0.05805935 0.28263175]
#  [0.15816387 0.31776709]]
